# %%
# Configuration
from dotenv import dotenv_values

config = dotenv_values(".env")
graphql_endpoint = config["DRUPAL_GRAPHQL_URL"]
course_acronym = config["DRUPAL_COURSE_ACRONYM"]

api_course_book = f"{config['DRUPAL_JSONAPI_URL']}/node/book"
api_course_group = f"{config['DRUPAL_JSONAPI_URL']}/group/course"
api_course_group_relationship = (
    f"{config['DRUPAL_JSONAPI_URL']}/group_relationship/course-group_node-book"
)
api_type_course_book = "node--book"
api_type_course_group = "group--course"
api_type_course_group_relationship = "group_relationship--course-group_node-book"
api_field_acronym = "field_acronym"

import os

json_filename = f"{config['DRUPAL_COURSE_ID']}.json"
course_json_path = os.path.join(config["COURSE_DATA_DIR"], json_filename)

# %%
# Load course json
from json import load

with open(file=course_json_path, mode="r", encoding="utf-8") as f:
    course_json = load(f)

# %%
from transform_course_json import apply_transformations

course_json = apply_transformations(course_json)

# %%
# Authentication
from requests import session

with session() as session:
    session.auth = (config["DRUPAL_USERNAME"], config["DRUPAL_PASSWORD"])
    # Headers are needed only for the JSON:API requests, but they don't impact the GraphQL ones, so it's ok to set for all
    session.headers.update(
        {
            "Accept": "application/vnd.api+json",
            "Content-Type": "application/vnd.api+json",
        }
    )

# %%
# List all book pages
res = session.post(
    graphql_endpoint,
    json={
        "query": """query GetAllBooks {
        books {
            id,
            title,
            body {
                value,
                summary
            },
            links {
                bid
            }
        }
    }""",
    },
)
res.json()
# Out:
# {'data': {'books': []}}

# %%
# Create new course book page
res = session.post(
    graphql_endpoint,
    json={
        "query": """mutation CreateCourseBookPage($data: BookInput!) {
        createBook(data: $data) {
            errors,
            book {
                id,
                title,
                body {
                    value,
                    summary,
                    format
                }
            }
        }
    }""",
        "variables": {
            "data": {
                "title": f"{course_acronym}: {course_json['course_name']}",
                "body": {
                    "value": course_json["overview"],
                },
            }
        },
    },
)
course_book_id = res.json()["data"]["createBook"]["book"]["id"]
res.json()
# Out:
# {'data': {'createBook': {'errors': [],
#    'book': {'id': '31',
#     'title': 'ADS: Advanced Database Systems (2022-2023)[SEM2]',
#     'body': {'value': '<h3>Welcome &amp; Learning Outcomes</h3><div id="inf-welcome"> \n <h4 class="inf">Welcome to Advanced Database Systems (2022-2023)[SEM2]</h4>  \n <h5><br>Learning Outcomes</h5> \n <p>On successful completion of this course, you should be able to:&nbsp;</p> \n <p>1. Describe how database management systems function internally. Interpret and comparatively criticise database systems architectures.</p> \n <p>2. Implement major components of a database management system and analyse their performance.</p> \n <p>3. Analyse and compare the fundamental query evaluation and concurrency control algorithms, identify strengths and weaknesses of query evaluation plans, and optimise query evaluation plans.</p> \n <p>4. Identify trade-offs among database systems techniques and contrast distributed / parallel techniques for OLTP and OLAP workloads.</p> \n</div> \n<p>\n <link rel="stylesheet" type="text/css" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-6735667_1"></p><br><h3>Course Outline</h3><div id="inf-course-outline"> \n <p>Lectures will cover roughly the following topics:</p> \n <ul> \n  <li>Database systems architectures, row stores and column stores, OLTP vs. OLAP, in-memory database systems</li> \n  <li>Storage: secondary-storage devices</li> \n  <li>Indexing: tree-based and hash-based techniques, learning indices from data (time permitting)</li> \n  <li>Query evaluation: theory of query evaluation, sorting and join processing, selection, projection, aggregation</li> \n  <li>Query optimisation: cardinality estimation, cost-based query optimisation, dynamic programming, rule-based optimisation</li> \n  <li>Transaction management: ACID properties, concurrency control, locking and multi-version protocols, crash recovery</li> \n  <li>Distributed database systems: parallel query evaluation, distributed transaction processing</li> \n  <li>Big data and NoSQL systems (time permitting)</li> \n </ul> \n</div> \n<p>The coursework will consist of one programming assignment on implementing parts of an educational database system written in Java. Prior experience with Java is recommended although not strictly required. Good knowledge of object-oriented programming is expected.</p><br><h3>Prerequisites</h3><p>The course assumes an understanding of algorithms and data structures (e.g., quick sort, merge sort, binary trees, hash tables, big-O notation) and some basic familiarity with complexity (e.g., PTIME, NP-complete). It is recommended that students have basic knowledge of databases (e.g., SQL and relational algebra) although key concepts will be covered in the course.</p> \n<p>A good level of object-oriented programming is assumed and will not be covered during lectures. The coursework will involve implementing different parts of a database system in Java.</p><br><h3>Recommended Textbooks</h3><p>Most lectures will closely follow this textbook:</p>\r\n<ul>\r\n<li>Database Management Systems (3rd edition, 2003) by Ramakrishnan and Gehrke <br>The UoE Library offers some but not all chapters online, go to "Library Resources".&nbsp;</li>\r\n</ul>\r\n<p>The lectures on conjunctive queries (weeks 2 &amp; 3) will refer to chapters from this textbook:</p>\r\n<ul>\r\n<li><a href="https://github.com/pdm-book/community">Principles of Databases</a> by Arenas, Barcelo, Libkin, Martens and Pieris</li>\r\n</ul><br><h3>Week-by-Week Course Overview</h3><p>Overview of course activities for ADBS 2022/23.</p>\r\n<p><em><span style="background-color: #fbeeb8;">The schedule is subject to change.</span>&nbsp;</em></p>\r\n<table style="border-collapse: collapse; width: 69.2249%; height: 788.5px;" height="212" border="1">\r\n<tbody>\r\n<tr style="height: 34px;">\r\n<td style="width: 7.1268%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><span style="color: #000000;">Week</span></td>\r\n<td style="width: 8.05065%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><s ...
#      'summary': None,
#      'format': 'full_html'}}}}}

# %%
# Make the course page into a new book
res = session.post(
    graphql_endpoint,
    json={
        "query": """mutation AddCourseBookOutline($id: ID!, $data: BookInput!) {
        updateBook(id: $id, data: $data) {
            errors,
            book {
                id,
                links {
                    nid,
                    bid
                }
            }
        }
    }""",
        "variables": {
            "id": course_book_id,
            "data": {
                "title": f"{course_acronym}: {course_json['course_name']}",
                "links": {"bid": course_book_id},
            },
        },
    },
)
res.json()
# Out:
# {'data': {'updateBook': {'errors': [],
#    'book': {'id': '31', 'links': {'nid': '31', 'bid': '31'}}}}}

# %%
# Get the new book page UUID
res = session.get(f"{api_course_book}?filter[drupal_internal__nid]={course_book_id}")
course_book_uuid = res.json()["data"][0]["id"]
res.json()
# Out:
# {'jsonapi': {'version': '1.0',
#   'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}},
#  'data': [{'type': 'node--book',
#    'id': 'f252129f-7ed7-4a78-83a3-7f6411a96e6c',
#    'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c?resourceVersion=id%3A31'}},
#    'attributes': {'drupal_internal__nid': 31,
#     'drupal_internal__vid': 31,
#     'langcode': 'en',
#     'revision_timestamp': '2023-07-19T19:40:41+00:00',
#     'revision_log': None,
#     'status': True,
#     'title': 'ADS: Advanced Database Systems (2022-2023)[SEM2]',
#     'created': '2023-07-19T19:40:41+00:00',
#     'changed': '2023-07-19T19:40:41+00:00',
#     'promote': False,
#     'sticky': False,
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'path': {'alias': None, 'pid': None, 'langcode': 'en'},
#     'body': {'value': '<h3>Welcome &amp; Learning Outcomes</h3><div id="inf-welcome"> \n <h4 class="inf">Welcome to Advanced Database Systems (2022-2023)[SEM2]</h4>  \n <h5><br>Learning Outcomes</h5> \n <p>On successful completion of this course, you should be able to:&nbsp;</p> \n <p>1. Describe how database management systems function internally. Interpret and comparatively criticise database systems architectures.</p> \n <p>2. Implement major components of a database management system and analyse their performance.</p> \n <p>3. Analyse and compare the fundamental query evaluation and concurrency control algorithms, identify strengths and weaknesses of query evaluation plans, and optimise query evaluation plans.</p> \n <p>4. Identify trade-offs among database systems techniques and contrast distributed / parallel techniques for OLTP and OLAP workloads.</p> \n</div> \n<p>\n <link rel="stylesheet" type="text/css" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-6735667_1"></p><br><h3>Course Outline</h3><div id="inf-course-outline"> \n <p>Lectures will cover roughly the following topics:</p> \n <ul> \n  <li>Database systems architectures, row stores and column stores, OLTP vs. OLAP, in-memory database systems</li> \n  <li>Storage: secondary-storage devices</li> \n  <li>Indexing: tree-based and hash-based techniques, learning indices from data (time permitting)</li> \n  <li>Query evaluation: theory of query evaluation, sorting and join processing, selection, projection, aggregation</li> \n  <li>Query optimisation: cardinality estimation, cost-based query optimisation, dynamic programming, rule-based optimisation</li> \n  <li>Transaction management: ACID properties, concurrency control, locking and multi-version protocols, crash recovery</li> \n  <li>Distributed database systems: parallel query evaluation, distributed transaction processing</li> \n  <li>Big data and NoSQL systems (time permitting)</li> \n </ul> \n</div> \n<p>The coursework will consist of one programming assignment on implementing parts of an educational database system written in Java. Prior experience with Java is recommended although not strictly required. Good knowledge of object-oriented programming is expected.</p><br><h3>Prerequisites</h3><p>The course assumes an understanding of algorithms and data structures (e.g., quick sort, merge sort, binary trees, hash tables, big-O notation) and some basic familiarity with complexity (e.g., PTIME, NP-complete). It is recommended that students have basic knowledge of databases (e.g., SQL and relational algebra) although key concepts will be covered in the course.</p> \n<p>A good level of object-oriented programming is assumed and will not be covered during lectures. The coursework will involve implementing different parts of a database system in Java.</p><br><h3>Recommended Textbooks</h3><p>Most lectures will closely follow this textbook:</p>\r\n<ul>\r\n<li>Database Management Systems (3rd edition, 2003) by Ramakrishnan and Gehrke <br>The UoE Library offers some but not all chapters online, go to "Library Resources".&nbsp;</li>\r\n</ul>\r\n<p>The lectures on conjunctive queries (weeks 2 &amp; 3) will refer to chapters from this textbook:</p>\r\n<ul>\r\n<li><a href="https://github.com/pdm-book/community">Principles of Databases</a> by Arenas, Barcelo, Libkin, Martens and Pieris</li>\r\n</ul><br><h3>Week-by-Week Course Overview</h3><p>Overview of course activities for ADBS 2022/23.</p>\r\n<p><em><span style="background-color: #fbeeb8;">The schedule is subject to change.</span>&nbsp;</em></p>\r\n<table style="border-collapse: collapse; width: 69.2249%; height: 788.5px;" height="212" border="1">\r\n<tbody>\r\n<tr style="height: 34px;">\r\n<td style="width: 7.1268%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><span style="color: #000000;">Week</span></td>\r\n<td style="width: 8.05065%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><s ...
#      'format': 'full_html',
#      'processed': '<h3>Welcome &amp; Learning Outcomes</h3><div id="inf-welcome"> \n <h4 class="inf">Welcome to Advanced Database Systems (2022-2023)[SEM2]</h4>  \n <h5><br />Learning Outcomes</h5> \n <p>On successful completion of this course, you should be able to:\xa0</p> \n <p>1. Describe how database management systems function internally. Interpret and comparatively criticise database systems architectures.</p> \n <p>2. Implement major components of a database management system and analyse their performance.</p> \n <p>3. Analyse and compare the fundamental query evaluation and concurrency control algorithms, identify strengths and weaknesses of query evaluation plans, and optimise query evaluation plans.</p> \n <p>4. Identify trade-offs among database systems techniques and contrast distributed / parallel techniques for OLTP and OLAP workloads.</p> \n</div> \n<p>\n <link rel="stylesheet" type="text/css" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-6735667_1" /></p><br /><h3>Course Outline</h3><div id="inf-course-outline"> \n <p>Lectures will cover roughly the following topics:</p> \n <ul><li>Database systems architectures, row stores and column stores, OLTP vs. OLAP, in-memory database systems</li> \n  <li>Storage: secondary-storage devices</li> \n  <li>Indexing: tree-based and hash-based techniques, learning indices from data (time permitting)</li> \n  <li>Query evaluation: theory of query evaluation, sorting and join processing, selection, projection, aggregation</li> \n  <li>Query optimisation: cardinality estimation, cost-based query optimisation, dynamic programming, rule-based optimisation</li> \n  <li>Transaction management: ACID properties, concurrency control, locking and multi-version protocols, crash recovery</li> \n  <li>Distributed database systems: parallel query evaluation, distributed transaction processing</li> \n  <li>Big data and NoSQL systems (time permitting)</li> \n </ul></div> \n<p>The coursework will consist of one programming assignment on implementing parts of an educational database system written in Java. Prior experience with Java is recommended although not strictly required. Good knowledge of object-oriented programming is expected.</p><br /><h3>Prerequisites</h3><p>The course assumes an understanding of algorithms and data structures (e.g., quick sort, merge sort, binary trees, hash tables, big-O notation) and some basic familiarity with complexity (e.g., PTIME, NP-complete). It is recommended that students have basic knowledge of databases (e.g., SQL and relational algebra) although key concepts will be covered in the course.</p> \n<p>A good level of object-oriented programming is assumed and will not be covered during lectures. The coursework will involve implementing different parts of a database system in Java.</p><br /><h3>Recommended Textbooks</h3><p>Most lectures will closely follow this textbook:</p>\n<ul><li>Database Management Systems (3rd edition, 2003) by Ramakrishnan and Gehrke <br />The UoE Library offers some but not all chapters online, go to "Library Resources".\xa0</li>\n</ul><p>The lectures on conjunctive queries (weeks 2 &amp; 3) will refer to chapters from this textbook:</p>\n<ul><li><a href="https://github.com/pdm-book/community">Principles of Databases</a> by Arenas, Barcelo, Libkin, Martens and Pieris</li>\n</ul><br /><h3>Week-by-Week Course Overview</h3><p>Overview of course activities for ADBS 2022/23.</p>\n<p><em><span style="background-color: #fbeeb8;">The schedule is subject to change.</span>\xa0</em></p>\n<table style="border-collapse: collapse; width: 69.2249%; height: 788.5px;" height="212" border="1"><tbody><tr style="height: 34px;"><td style="width: 7.1268%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><span style="color: #000000;">Week</span></td>\n<td style="width: 8.05065%; height: 34px; background-color: #3598db; border-color: #ecf0f1; border-style: double;"><span style="color: #000000;">Date</span></t ...
#      'summary': None}},
#    'relationships': {'node_type': {'data': {'type': 'node_type--node_type',
#       'id': '56b4ed5a-2049-4246-ab4a-63d8bff55ba5',
#       'meta': {'drupal_internal__target_id': 'book'}},
#      'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/node_type?resourceVersion=id%3A31'},
#       'self': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/relationships/node_type?resourceVersion=id%3A31'}}},
#     'revision_uid': {'data': {'type': 'user--user',
#       'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0',
#       'meta': {'drupal_internal__target_id': 1}},
#      'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/revision_uid?resourceVersion=id%3A31'},
#       'self': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/relationships/revision_uid?resourceVersion=id%3A31'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0',
#       'meta': {'drupal_internal__target_id': 1}},
#      'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/uid?resourceVersion=id%3A31'},
#       'self': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book/f252129f-7ed7-4a78-83a3-7f6411a96e6c/relationships/uid?resourceVersion=id%3A31'}}}}}],
#  'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/node/book?filter%5Bdrupal_internal__nid%5D=31'}}}

# %%
# Create a new group for the course
res = session.post(
    api_course_group,
    json={
        "data": {
            "type": api_type_course_group,
            "attributes": {
                "label": course_json["course_name"],
                api_field_acronym: course_acronym,
            },
        }
    },
)
course_group_uuid = res.json()["data"]["id"]
res.json()
# Out:
# {'jsonapi': {'version': '1.0',
#   'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}},
#  'data': {'type': 'group--course',
#   'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78',
#   'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78?resourceVersion=id%3A4'}},
#   'attributes': {'drupal_internal__id': 4,
#    'drupal_internal__revision_id': 4,
#    'langcode': 'en',
#    'revision_created': '2023-07-19T19:40:43+00:00',
#    'revision_log_message': None,
#    'status': True,
#    'label': 'Advanced Database Systems (2022-2023)[SEM2]',
#    'created': '2023-07-19T19:40:43+00:00',
#    'changed': '2023-07-19T19:40:43+00:00',
#    'path': {'alias': None, 'pid': None, 'langcode': 'en'},
#    'default_langcode': True,
#    'revision_translation_affected': True,
#    'field_acronym': 'ADS'},
#   'relationships': {'group_type': {'data': {'type': 'group_type--group_type',
#      'id': 'b7bba7fe-105a-466c-9984-0303957b6883',
#      'meta': {'drupal_internal__target_id': 'course'}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/group_type?resourceVersion=id%3A4'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/relationships/group_type?resourceVersion=id%3A4'}}},
#    'revision_user': {'data': {'type': 'user--user',
#      'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0',
#      'meta': {'drupal_internal__target_id': 1}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/revision_user?resourceVersion=id%3A4'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/relationships/revision_user?resourceVersion=id%3A4'}}},
#    'uid': {'data': {'type': 'user--user',
#      'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0',
#      'meta': {'drupal_internal__target_id': 1}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/uid?resourceVersion=id%3A4'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course/74cc7c29-7910-40d9-985f-4c6fa702ec78/relationships/uid?resourceVersion=id%3A4'}}}}},
#  'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group/course'}}}

# %%
# Then create a relationship linking the new course book page to the course group
res = session.post(
    api_course_group_relationship,
    json={
        "data": {
            "type": api_type_course_group_relationship,
            "attributes": {
                "label": f"{course_acronym}: {course_json['course_name']}",
            },
            "relationships": {
                "entity_id": {
                    "data": {
                        "type": api_type_course_book,
                        "id": course_book_uuid,
                    }
                },
                "gid": {
                    "data": {
                        "type": api_type_course_group,
                        "id": course_group_uuid,
                    }
                },
            },
        }
    },
)
# If you get HTTP 500 error, see note in the README file
res.json()
# Out:
# {'jsonapi': {'version': '1.0',
#   'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}},
#  'data': {'type': 'group_relationship--course-group_node-book',
#   'id': '40e58f47-dd62-4801-94fc-9f18950d2674',
#   'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674'}},
#   'attributes': {'drupal_internal__id': 36,
#    'langcode': 'en',
#    'label': 'ADS: Advanced Database Systems (2022-2023)[SEM2]',
#    'created': '2023-07-19T19:40:46+00:00',
#    'changed': '2023-07-19T19:40:46+00:00',
#    'plugin_id': 'group_node:book',
#    'path': {'alias': None, 'pid': None, 'langcode': 'en'},
#    'default_langcode': True},
#   'relationships': {'group_relationship_type': {'data': None,
#     'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/relationships/group_relationship_type'}}},
#    'uid': {'data': {'type': 'user--user',
#      'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0',
#      'meta': {'drupal_internal__target_id': 1}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/uid'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/relationships/uid'}}},
#    'gid': {'data': {'type': 'group--course',
#      'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78',
#      'meta': {'drupal_internal__target_id': 4}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/gid'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/relationships/gid'}}},
#    'entity_id': {'data': {'type': 'node--book',
#      'id': 'f252129f-7ed7-4a78-83a3-7f6411a96e6c',
#      'meta': {'drupal_internal__target_id': 31}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/entity_id'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/relationships/entity_id'}}},
#    'group_type': {'data': {'type': 'group_type--group_type',
#      'id': 'b7bba7fe-105a-466c-9984-0303957b6883',
#      'meta': {'drupal_internal__target_id': 'course'}},
#     'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/group_type'},
#      'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/40e58f47-dd62-4801-94fc-9f18950d2674/relationships/group_type'}}}}},
#  'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}

# %%
# Now add pages for all the course content
def link_book_page_to_group(page_id, title, group_uuid):
    res = session.get(f"{api_course_book}?filter[drupal_internal__nid]={page_id}")
    page_uuid = res.json()["data"][0]["id"]
    res = session.post(
        api_course_group_relationship,
        json={
            "data": {
                "type": api_type_course_group_relationship,
                "attributes": {
                    "label": f"{course_acronym}: {title}",
                },
                "relationships": {
                    "entity_id": {
                        "data": {
                            "type": api_type_course_book,
                            "id": page_uuid,
                        }
                    },
                    "gid": {
                        "data": {
                            "type": api_type_course_group,
                            "id": group_uuid,
                        }
                    },
                },
            }
        },
    )
    print(res.json())


def create_outline_page(title, book_id, weight):
    res = session.post(
        graphql_endpoint,
        json={
            "query": """mutation CreateCourseOutlinePage($data: BookInput!) {
            createBook(data: $data) {
                errors,
                book {
                    id,
                    title,
                    links {
                        bid,
                        pid,
                        weight,
                    }
                }
            }
        }""",
            "variables": {
                "data": {
                    "title": f"{course_acronym}: {title}",
                    "links": {
                        "bid": book_id,
                        "pid": book_id,
                        "weight": weight,
                    },
                }
            },
        },
    )
    print(res.json())
    return res.json()["data"]["createBook"]["book"]["id"]


def create_content_page(title, summary, body, book_id, parent_id, weight):
    res = session.post(
        graphql_endpoint,
        json={
            "query": """mutation CreateCourseContentPage($data: BookInput!) {
            createBook(data: $data) {
                errors,
                book {
                    id,
                    title,
                    body {
                        value,
                        summary,
                        format,
                    },
                    links {
                        bid,
                        pid,
                        weight,
                    }
                }
            }
        }""",
            "variables": {
                "data": {
                    "title": f"{course_acronym}: {title}",
                    "body": {
                        "summary": summary,
                        "value": body,
                    },
                    "links": {
                        "bid": book_id,
                        "pid": parent_id,
                        "weight": weight,
                    },
                }
            },
        },
    )
    print(res.json())
    return res.json()["data"]["createBook"]["book"]["id"]


def create_content_pages_rec(toc_subitem, book_id, parent_id, weight, group_uuid):
    page_id = create_content_page(
        toc_subitem["title"],
        toc_subitem["description"],
        toc_subitem["body"],
        book_id,
        parent_id,
        weight,
    )
    link_book_page_to_group(page_id, toc_subitem["title"], group_uuid)
    for child_index, child in enumerate(toc_subitem["children"]):
        create_content_pages_rec(child, book_id, page_id, child_index, group_uuid)


# Add a content pages linked to the course book
for toc_index, toc_item in enumerate(course_json["toc"]):
    toc_page_id = create_outline_page(toc_item["title"], course_book_id, toc_index)
    link_book_page_to_group(toc_page_id, toc_item["title"], course_group_uuid)
    for child_index, child in enumerate(toc_item["children"]):
        create_content_pages_rec(
            child, course_book_id, toc_page_id, child_index, course_group_uuid
        )
# Out:
# {'data': {'createBook': {'errors': [], 'book': {'id': '32', 'title': 'ADS: Course Materials', 'links': {'bid': '31', 'pid': '31', 'weight': 0}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'e2bc9384-1357-44d2-af69-4668b4fa587c', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c'}}, 'attributes': {'drupal_internal__id': 37, 'langcode': 'en', 'label': 'ADS: Course Materials', 'created': '2023-07-19T19:40:48+00:00', 'changed': '2023-07-19T19:40:48+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '37e6ab16-b58a-4832-bb6f-a1562a685bb7', 'meta': {'drupal_internal__target_id': 32}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e2bc9384-1357-44d2-af69-4668b4fa587c/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '33', 'title': 'ADS: Lecture Recordings', 'body': {'value': '<p>This provides you with access to any lecture recordings available for this course. You will need to select this link once, before you can access any direct links to a lecture recording.</p>\r\n<p><link rel="stylesheet" type="text/css" href="https://www.learn.ed.ac.uk/bbcswebdav/pid-5859823-dt-content-rid-6735667_1/xid-6735667_1" /></p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 0}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': '011613da-8335-4705-bef7-44ca0e1b60da', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da'}}, 'attributes': {'drupal_internal__id': 38, 'langcode': 'en', 'label': 'ADS: Lecture Recordings', 'created': '2023-07-19T19:40:50+00:00', 'changed': '2023-07-19T19:40:50+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '0a072cf9-ecc4-4154-a96d-82275eb13f51', 'meta': {'drupal_internal__target_id': 33}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/011613da-8335-4705-bef7-44ca0e1b60da/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '34', 'title': 'ADS: Week 1: Intro, SQL, Relational Algebra', 'body': {'value': '<h3>Lecture 01: Course Introduction</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 1of RG</li>\r\n<li><strong>Slides:</strong> <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33496468_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33496469_1" target="_blank" rel="noopener">2 x 2</a></li>\r\n</ul><br><h3>Lecture 02: SQL</h3><ul> \n <li><strong>Reading:&nbsp;</strong>RG Chapter 5</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33495973_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33495974_1" target="_blank" rel="noopener">2 x 2</a><br>&nbsp;</li> \n</ul><br><h3>Lecture 03: Relational Algebra</h3><ul> \n <li><strong>Reading:</strong> RG Chapters 4.1 &amp; 4.2</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33495975_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33495976_1" target="_blank" rel="noopener">2 x 2</a><br>&nbsp;</li> \n</ul><br><h3>Quiz 01: Course Introduction</h3><p>This quiz is about the course introduction. There are 5 questions, each worth 20 points.&nbsp;</p>\r\n<p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p><br><h3>Quiz 02: SQL</h3><p>This quiz is about SQL. There are 10 questions, each worth 10 points.</p>\r\n<p><span style="font-size: 10pt;">The quiz allows two attempts. The higher score of the two attempts is the final score. </span></p>\r\n<p><span style="font-size: 10pt;">Time estimate: up to 30 minutes</span></p>\r\n<ul style="list-style-type: none;" id="content_listContainer">\r\n<li id="contentListItem:_8311889_1"></li>\r\n</ul><br><h3>Quiz 03: Relational Algebra</h3><p>This quiz is about Relational Algebra. There are 10 questions, each worth 10 points.&nbsp;</p>\r\n<div>\r\n<div>\r\n<div>The quiz allows two attempts. The higher score of the two attempts is the final score.</div>\r\n</div>\r\n</div>\r\n<ul style="list-style-type: none;" id="content_listContainer">\r\n<li id="contentListItem:_8311889_1"></li>\r\n</ul>\r\n<p>Remember that the relational algebra is defined using the set semantics, meaning that relation instances cannot have duplicates.</p>\r\n<p>Time estimate: up to 30 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 1}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': '43e78ff3-a865-4780-8b74-5c68dcc7e128', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128'}}, 'attributes': {'drupal_internal__id': 39, 'langcode': 'en', 'label': 'ADS: Week 1: Intro, SQL, Relational Algebra', 'created': '2023-07-19T19:40:52+00:00', 'changed': '2023-07-19T19:40:52+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '3b99d07d-625b-4cab-815e-bc04cd88d5db', 'meta': {'drupal_internal__target_id': 34}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/43e78ff3-a865-4780-8b74-5c68dcc7e128/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '35', 'title': 'ADS: Week 2: Conjunctive Queries', 'body': {'value': '<h3>Lecture 04: Conjunctive Queries (CQ): Syntax and Semantics</h3><p><strong>Reading:</strong> Chapters 13 and 14 of <a href="https://github.com/pdm-book/community">PDB</a></p>\r\n<p>Recording of the online lecture is available under Live Classroom --&gt; Blackboard Collaborate Ultra --&gt; Menu ≡ --&gt; Recordings.</p><br><h3>Lecture 05 &amp; 06: CQ Evaluation &amp; Static Analysis</h3><p><strong>Reading: </strong>Chapters 15 and 16 of <a href="https://github.com/pdm-book/community">PDB</a></p>\r\n<div>\r\n<div>\r\n<div>Recording of the online lecture is available under Live Classroom --&gt; Blackboard Collaborate Ultra --&gt; Menu ≡ --&gt; Recordings.</div>\r\n</div>\r\n</div>\r\n<ul style="list-style-type: none;" id="content_listContainer">\r\n<li id="contentListItem:_8321848_1"></li>\r\n</ul>\r\n<p><br></p><br><h3>Quiz 04: Conjunctive Queries: Syntax and Semantics</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p><br><h3>Quiz 05 & 06: CQ Evaluation & Static Analysis</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 2}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': '9880a368-57ed-4735-a392-637e4b737740', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740'}}, 'attributes': {'drupal_internal__id': 40, 'langcode': 'en', 'label': 'ADS: Week 2: Conjunctive Queries', 'created': '2023-07-19T19:40:54+00:00', 'changed': '2023-07-19T19:40:54+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': 'ca6037bc-4d1a-4004-824b-aece55e02235', 'meta': {'drupal_internal__target_id': 35}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9880a368-57ed-4735-a392-637e4b737740/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '36', 'title': 'ADS: Week 3: Conjunctive Queries (Part 2)', 'body': {'value': '<h3>Lecture 07: CQ Minimization</h3><p><strong>Reading:</strong> Chapter 17 of <a href="https://github.com/pdm-book/community">PDB</a></p><br><h3>Lecture 08 &amp; 09: Fast CQ Evaluation</h3><p><strong>Reading:</strong> Chapter 18 of <a href="https://github.com/pdm-book/community">PDB</a></p><br><h3>Quiz 07: CQ Minimization</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p><br><h3>Quiz 08 & 09: Fast CQ Evaluation</h3><blockquote>\r\n<p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p>\r\n</blockquote>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 3}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2'}}, 'attributes': {'drupal_internal__id': 41, 'langcode': 'en', 'label': 'ADS: Week 3: Conjunctive Queries (Part 2)', 'created': '2023-07-19T19:40:56+00:00', 'changed': '2023-07-19T19:40:56+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': 'f59317a7-fc04-477f-af81-692976effba0', 'meta': {'drupal_internal__target_id': 36}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/abab2f9d-f585-4ef1-8e54-c3c03a8e5aa2/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '37', 'title': 'ADS: Week 4: Database Storage', 'body': {'value': '<h3>Lecture 10: Hardware &amp; Disk Space Management</h3><ul> \n <li><strong>Reading:</strong> Chapters 1, 9.1, 9.3 of RG</li> \n <li><strong>Slides:</strong>&nbsp;<a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926066_1" alt="">1 per page</a>, <a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926067_1" alt="">2 x 2.pdf</a></li> \n</ul><br><h3>Lecture 11: Buffer Management</h3><ul> \n <li><strong>Reading:</strong> Chapter 9.4 of RG</li> \n <li><strong>Slides: </strong><a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926062_1" alt="">1 per page</a>, <a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926063_1" alt="">2 x 2</a></li> \n</ul><br><h3>Lecture 12: Files, Pages &amp; Records</h3><ul> \n <li><strong>Reading:</strong> Chapters 9.5-9.7 of RG</li> \n <li><strong>Slides: </strong><a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926064_1" alt="">1 per page</a>, <a rel="noopener" target="_blank" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-33926065_1" alt="">2 x 2</a></li> \n</ul><br><h3>Quiz 10: Hardware & Disk Space Management</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p>\r\n<p>NOTE: Questions 9 and 10 are about the material that will be covered on Wednesday.&nbsp;</p><br><h3>Quiz 11: Buffer Management</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p><br><h3>Quiz 12: Files, Pages & Records</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 15 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 4}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': '9562540c-044b-4e85-b838-41f1c9004bb0', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0'}}, 'attributes': {'drupal_internal__id': 42, 'langcode': 'en', 'label': 'ADS: Week 4: Database Storage', 'created': '2023-07-19T19:40:58+00:00', 'changed': '2023-07-19T19:40:58+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '8d765e59-0dbd-44c5-9eb4-4627a24155e0', 'meta': {'drupal_internal__target_id': 37}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/9562540c-044b-4e85-b838-41f1c9004bb0/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '38', 'title': 'ADS: Week 5: File Organisations & Indexing', 'body': {'value': '<h3>Lecture 13: File Organisations</h3><ul> \n <li><strong>Reading:</strong> Chapter 8 of RG</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060234_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060235_1" target="_blank" rel="noopener">2 x 2</a><br>&nbsp;<strong><br>&nbsp;</strong></li> \n</ul><br><h3>Quiz 13: File Organisations</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p><br><h3>Lecture 14: Tree-Structured Indexing</h3><ul> \n <li><strong>Reading:</strong> Chapter 10 of RG</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060236_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060237_1" target="_blank" rel="noopener">2 x 2</a><strong><br>&nbsp;</strong></li> \n</ul><br><h3>Quiz 14: Tree-Structured Indexing</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p><br><h3>Lecture 15: Hash-Based Indexing</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 11 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060239_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34060240_1" target="_blank" rel="noopener">2 x 2</a><strong>&nbsp;</strong></li>\r\n</ul>\r\n<p><strong>&nbsp;</strong></p><br><h3>Quiz 15: Hash-Based Indexing</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 5}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'e02dba9d-fca9-4312-aef0-acc0470f1f14', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14'}}, 'attributes': {'drupal_internal__id': 43, 'langcode': 'en', 'label': 'ADS: Week 5: File Organisations & Indexing', 'created': '2023-07-19T19:41:00+00:00', 'changed': '2023-07-19T19:41:00+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '150a3498-fa38-4bfd-aea2-bf2e4bc7f1ba', 'meta': {'drupal_internal__target_id': 38}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e02dba9d-fca9-4312-aef0-acc0470f1f14/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '39', 'title': 'ADS: Week 6: Access Methods, Sorting & Aggregation, Joins', 'body': {'value': '<h3>Lecture 16: Access Methods</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 14 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287975_1" target="_blank" rel="noopener">1 per page</a><strong>, </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287976_1" target="_blank" rel="noopener">2x2</a><strong><br></strong></li>\r\n</ul><br><h3>Quiz 16: Access Methods</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p><br><h3>Lecture 17: External Sorting &amp; Aggregation</h3><ul>\r\n<li><strong>Reading:</strong> Chapters 13 &amp; 14 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287979_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287980_1" target="_blank" rel="noopener">2x2</a><br><strong>&nbsp;</strong><strong><br></strong></li>\r\n</ul><br><h3>Quiz 17: External Sorting & Aggregation</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p><br><h3>Lecture 18: Joins</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 14 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287977_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34287978_1" target="_blank" rel="noopener">2x2</a><strong><br>&nbsp;</strong><strong><br></strong></li>\r\n</ul><br><h3>Quiz 18: Joins</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 6}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'c69d981b-719c-4f60-ae9d-e620b4f254e2', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2'}}, 'attributes': {'drupal_internal__id': 44, 'langcode': 'en', 'label': 'ADS: Week 6: Access Methods, Sorting & Aggregation, Joins', 'created': '2023-07-19T19:41:03+00:00', 'changed': '2023-07-19T19:41:03+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '3379dcd1-e38c-441e-941e-2e34d521b597', 'meta': {'drupal_internal__target_id': 39}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/c69d981b-719c-4f60-ae9d-e620b4f254e2/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '40', 'title': 'ADS: Week 7: Processing Models & Plan Space', 'body': {'value': '<h3>Lecture 19: Query Evaluation - Processing Models</h3><ul> \n <li><strong>Reading:</strong> Chapter 14 of RG</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435115_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435116_1" target="_blank" rel="noopener">2 x 2</a><strong><br>&nbsp;</strong><strong><br></strong></li> \n</ul><br><h3>Quiz 19: Query Evaluation - Processing Models</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p><br><h3>Lecture 20: Query Optimisation - Plan Space</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 15 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435113_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435119_1" target="_blank" rel="noopener">2 x 2</a><strong><br></strong></li>\r\n</ul><br><h3>Lecture 21: Query Optimisation - Plan Space Example</h3><ul> \n <li><strong>Reading:</strong> Chapter 15 of RG</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435117_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34435118_1" target="_blank" rel="noopener">2 x 2</a><strong><br></strong><strong><br></strong></li> \n</ul><br><h3>Quiz 20 & 21: Query Optimisation - Plan Space</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 10 minutes</p>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '32', 'weight': 7}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'ce72b3c9-f277-4105-9ce9-8907c158a4e7', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7'}}, 'attributes': {'drupal_internal__id': 45, 'langcode': 'en', 'label': 'ADS: Week 7: Processing Models & Plan Space', 'created': '2023-07-19T19:41:05+00:00', 'changed': '2023-07-19T19:41:05+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': 'e72eb05e-5cbb-4bfb-aca6-8c03ff41ce14', 'meta': {'drupal_internal__target_id': 40}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/ce72b3c9-f277-4105-9ce9-8907c158a4e7/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '41', 'title': 'ADS: Week 8: Costing, Search & Transactions', 'body': {'value': '<h3>Lecture 22: Query Optimisation - Costing</h3><ul> \n <li><strong>Reading:</strong> Chapter 15 of RG</li> \n <li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34553101_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34553102_1" target="_blank" rel="noopener">2 x 2</a><strong><br>&nbsp;</strong><strong><br></strong></li> \n</ul><br><h3>Quiz 22: Query Optimisation - Costing</h3><p>The quiz allows two attempts. The higher score of the two attempts is the final score.</p>\r\n<p>Time estimate: up to 20 minutes</p><br><h3>Lecture 23: Query Optimisation - Search</h3><ul>\r\n<li><strong>Reading:</strong> Chapter 15 of RG</li>\r\n<li><strong>Slides: </strong><a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34553105_1" target="_blank" rel="noopener">1 per page</a>, <a alt="" href="@X@EmbeddedFile.requestUrlStub@X@bbcswebdav/xid-34553143_1" target="_blank" rel="noopener">2 x 2</a>&nbsp;</li>\r\n</ul>\r\n<div style="width: 400px; overflow: hidden;">\r\n<div id="container_0.4070902988327101" class="hide-icon hidden mce-visual-caret-hidden" style="margin-top: 30px; float: left; clear: left;">\r\n<div style="float: left; clear: left;">\r\n<div style="float: left; clear: both; margin-bottom: 13px;"><a class="lb" style="text-decoration: none; color: #333333;" href="@X@EmbeddedFile.requestUrlStub@X@/webapps/osv-kaltura-BB5d1b15b77a8ac/LtiMashupPlayIframeWrapperResponsive?playUrl=/browseandembed/index/media/entryid/1_pg8u9gca/showDescription/false/showTitle/false/showTags/false/showDuration/false/showOwner/false/showUploadDate/false/playerSize/400x285/playerSkin/32599141/&amp;course_id=@X@course.pk_string@X@" target="_self"> <b style="margin-bottom: 20px; font-size: 14px;">Lecture08-4: Query Optimisation - Search (40:17)</b><br><br><img border="0" alt="Lecture08-4: Query Optimisation - Search (40:17)" src="https://cfvod.kaltura.com/p/2010292/sp/201029200/thumbnail/entry_id/1_pg8u9gca/version/100001"> </a></div>\r\n</div>\r\n<div>\r\n<table style="margin: 0px !important; border-collapse: collapse;">\r\n<tbody>\r\n<tr style="vertical-align: top;">\r\n<td style="padding: 0px !important;">Duration:</td>\r\n<td style="padding: 0px 0px 0px 20px !important;">40:17</td>\r\n</tr>\r\n<tr style="vertical-align: top;">\r\n<td style="padding: 0px !important;">Added:</td>\r\n<td style="padding: 0px 0px 0px 20px !important;">09 Mar 2021 08:55 PM</td>\r\n</tr>\r\n<tr style="vertical-align: top;">\r\n<td style="padding: 0px !important;">Added By:</td>\r\n<td style="padding: 0px 0px 0px 20px !important;">Milos Nikolic</td>\r\n</tr>\r\n<tr style="vertical-align: top;">\r\n<td style="padding: 0px !important;">Description:</td>\r\n<td style="padding: 0px 0px 0px 20px !important;">\r\n<div title="Week 8: Lecture08-4: Query Optimisation - Search">Week 8: Lecture08-4: Query Optimisation - Search</div>\r\n</td>\r\n</tr>\r\n<tr style="vertical-align: top;">\r\n<td style="padding: 0px !important;">Tags:</td>\r\n<td style="padding: 0px 0px 0px 20px !important;">query optimisation, databases, dynamic programming, relation, query, join, plan, plans, tuples, relations, cost, instance, plants, trees, implementations, access, table, result, output, operator, scan, evaluation, attribute</td>\r\n</tr>\r\n<tr>\r\n<td colspan="100" style="position: relative;"><input type="button" class="browse" style="position: relative; left: -2px;" id="0.4070902988327101_a" value="Deep Link" title="Deep Link" onclick="\r\n                                var div = document.getElementById(\'0.4070902988327101_div\');\r\n                                div.style.display = div.style.display == \'none\' ? \'block\' : \'none\';\r\n\r\n                                var container = document.getElementById(\'container_0.4070902988327101\');\r\n   ...
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'de2fbb86-1ec3-4e09-9dfc-5684cbfbed68', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68'}}, 'attributes': {'drupal_internal__id': 46, 'langcode': 'en', 'label': 'ADS: Week 8: Costing, Search & Transactions', 'created': '2023-07-19T19:41:07+00:00', 'changed': '2023-07-19T19:41:07+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '45646c77-7793-4dfc-9cc2-70e22cc49db7', 'meta': {'drupal_internal__target_id': 41}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/de2fbb86-1ec3-4e09-9dfc-5684cbfbed68/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# ...
# {'data': {'createBook': {'errors': [], 'book': {'id': '70', 'title': 'ADS: Help and Support', 'links': {'bid': '31', 'pid': '31', 'weight': 6}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': '8295571f-2b94-4168-9696-a59f9965c425', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425'}}, 'attributes': {'drupal_internal__id': 75, 'langcode': 'en', 'label': 'ADS: Help and Support', 'created': '2023-07-19T19:42:08+00:00', 'changed': '2023-07-19T19:42:08+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': '94a3b7fc-b838-4ba3-afa8-c7bb05a8c18d', 'meta': {'drupal_internal__target_id': 70}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/8295571f-2b94-4168-9696-a59f9965c425/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '71', 'title': 'ADS: Useful Links: Informatics', 'body': {'value': '<div id="inf-help-links"> \n <p>The <a href="https://web.inf.ed.ac.uk/infweb/student-services/ito/students" target="_blank" rel="noopener">Informatics intranet</a> has useful information on the following:</p> \n <ul> \n  <li>Induction</li> \n  <li>Student handbooks, with detailed information on \n   <ul> \n    <li>courses</li> \n    <li>assessment</li> \n    <li>support, and</li> \n    <li>contacts for each year.</li> \n   </ul> </li> \n </ul> \n <p>You can also email the Informatics Teaching Organisation (ITO) at&nbsp;<a href="mailto:ito@inf.ed.ac.uk" target="_blank" rel="noopener">ito@inf.ed.ac.uk</a>&nbsp; or the Student Support Team (SST) at&nbsp;<a href="mailto:inf-sst@inf.ed.ac.uk" target="_blank" rel="noopener">inf-sst@inf.ed.ac.uk.</a></p> \n</div>', 'summary': '', 'format': 'full_html'}, 'links': {'bid': '31', 'pid': '70', 'weight': 0}}}}}
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'cdb84c1a-ef4f-4e9d-95c7-0d1806b181db', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db'}}, 'attributes': {'drupal_internal__id': 76, 'langcode': 'en', 'label': 'ADS: Useful Links: Informatics', 'created': '2023-07-19T19:42:10+00:00', 'changed': '2023-07-19T19:42:10+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': 'b40775bd-e1d7-49e1-aa55-6a11494fa0b4', 'meta': {'drupal_internal__target_id': 71}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/cdb84c1a-ef4f-4e9d-95c7-0d1806b181db/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
# {'data': {'createBook': {'errors': [], 'book': {'id': '72', 'title': 'ADS: Useful links (opens in new window)', 'body': {'value': '<div id="inf-help-links"> \n <h6>Help/support using Learn and other University systems</h6> \n <ul> \n  <li><a title="Learn Help and support" href="https://edin.ac/learn-help" target="_blank" rel="noopener">Help/support using Learn&nbsp;</a></li> \n  <li><a title="Timetable browser" href="https://edin.ac/timetable-browser" target="_blank" rel="noopener">Course timetable browser</a></li> \n  <li><a title="IT and Computing Help" href="https://edin.ac/it-help" target="_blank" rel="noopener">IT and Computing Help</a></li> \n  <li><a href="https://edin.ac/learn-accessibility" target="_blank" title="Learn accessibility statement" rel="noopener">Learn accessibility statement</a></li> \n  <li><a href="https://edin.ac/learn-terms-of-use" target="_blank" rel="noreferrer noopener">Learn Terms of Use</a></li> \n </ul> \n <h6>Student support information</h6> \n <ul> \n  <li><a title="Student services A-Z" href="https://edin.ac/student-services" target="_blank" rel="noopener">Student Services A-Z</a></li> \n  <li><a title="Appeals" href="https://edin.ac/appeals" target="_blank" rel="noopener">Appeals</a></li> \n  <li><a title="Accessible and inclusive learning" style="outline-style: none; outline-width: initial; font-size: 13px;" href="https://edin.ac/accessible-learning" target="_blank" rel="noopener">Accessible&nbsp;and inclusive&nbsp;learning</a></li> \n  <li><a href="https://edin.ac/assessment-regulations" target="_blank" rel="noopener">Assessment regulations</a></li> \n  <li><a href="https://edin.ac/common-marking-scheme" target="_blank" title="Extended Common Marking Scheme" rel="noopener">Extended Common Marking Scheme</a></li> \n  <li><a title="Dignity and Respect Policy" href="https://edin.ac/dignity-respect" target="_blank" rel="noopener">Dignity and Respect Policy</a></li> \n  <li><a title="Equality, Diversity and Inclusion" href="https://www.ed.ac.uk/equality-diversity/" target="_blank" rel="noopener">Equality, Diversity and Inclusion</a></li> \n  <li><a title="Health and safety" href="https://edin.ac/health-safety" target="_blank" rel="noopener">Health and safety policy</a></li> \n  <li><a title="Immigration" href="https://edin.ac/immigration" target="_blank" rel="noopener">Immigration</a></li> \n  <li><a title="Library " href="https://edin.ac/library-resources" target="_blank" rel="noopener">Library </a></li> \n  <li><a href="https://path.is.ed.ac.uk/" target="_blank" rel="noopener">PATH (course information)</a></li> \n  <li><a title="Peer Learning and Support" href="https://edin.ac/peer-support" target="_blank" rel="noopener">Peer Learning and Support</a></li> \n  <li><a title="Quality (The University’s Quality Framework)" href="https://edin.ac/quality" target="_blank" rel="noopener">Quality (The University’s Quality Framework)</a></li> \n  <li><a title="Extensions and Special Circumstances Service" href="https://edin.ac/special-circumstances" target="_blank" rel="noopener">Extensions and Special Circumstances Service</a></li> \n  <li><a title="Code of Student Conduct" href="https://edin.ac/code-of-conduct" target="_blank" rel="noopener">Code of Student Conduct</a></li> \n  <li><a title="Complaints" href="https://edin.ac/complaints" target="_blank" rel="noopener">Student complaints procedure</a></li> \n  <li><a title="Student disability service" href="https://edin.ac/disability-service" target="_blank" rel="noopener">Student disability service</a></li> \n  <li><a title="The Student Contract" href="https://edin.ac/student-contract" target="_blank" rel="noopener">The Student Contract</a></li> \n </ul> \n <h6>Student Rep Information</h6> \n <ul> \n  <li><a title="Find Your Reps (EUSA)" href="https://edin.ac/student-rep" target="_blank" rel="noopener">Find Your Reps (EUSA)</a></li> \n </ul> \n <h6></h6> \n <h6>Careers information</h6> \n <ul> \n  <li><span bb:beforeshowfunc="" bb:overwritenavitems=""  ...
# {'jsonapi': {'version': '1.0', 'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}}, 'data': {'type': 'group_relationship--course-group_node-book', 'id': 'e6173d26-99da-42da-becd-6d6d21886138', 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138'}}, 'attributes': {'drupal_internal__id': 77, 'langcode': 'en', 'label': 'ADS: Useful links (opens in new window)', 'created': '2023-07-19T19:42:12+00:00', 'changed': '2023-07-19T19:42:12+00:00', 'plugin_id': 'group_node:book', 'path': {'alias': None, 'pid': None, 'langcode': 'en'}, 'default_langcode': True}, 'relationships': {'group_relationship_type': {'data': None, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/relationships/group_relationship_type'}}}, 'uid': {'data': {'type': 'user--user', 'id': '40a313f1-a898-4954-a2c0-b8c05033d6e0', 'meta': {'drupal_internal__target_id': 1}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/uid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/relationships/uid'}}}, 'gid': {'data': {'type': 'group--course', 'id': '74cc7c29-7910-40d9-985f-4c6fa702ec78', 'meta': {'drupal_internal__target_id': 4}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/gid'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/relationships/gid'}}}, 'entity_id': {'data': {'type': 'node--book', 'id': 'dc7af809-c604-48ce-8dcc-af7aca2e334d', 'meta': {'drupal_internal__target_id': 72}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/entity_id'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/relationships/entity_id'}}}, 'group_type': {'data': {'type': 'group_type--group_type', 'id': 'b7bba7fe-105a-466c-9984-0303957b6883', 'meta': {'drupal_internal__target_id': 'course'}}, 'links': {'related': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/group_type'}, 'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book/e6173d26-99da-42da-becd-6d6d21886138/relationships/group_type'}}}}}, 'links': {'self': {'href': 'http://raspberrypi.local:8081/jsonapi/group_relationship/course-group_node-book'}}}
